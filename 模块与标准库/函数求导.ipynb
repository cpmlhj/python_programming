# %%
from sympy import Derivative, Symbol

x = Symbol("x")
y = x * x + 3 * x  + 2
d = Derivative(y, x)


d.doit()
d.doit().subs({"x": 10})
# Out:
# 23

# %%
from sympy.plotting import plot

plot(y, (x, -10, 10))
