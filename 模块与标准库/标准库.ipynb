# %%
from urllib import request
from html.parser import HTMLParser
from html.entities import name2codepoint

class MyHTMLParser(HTMLParser):
    def handle_starttag(self, tag, attrs):
        print("Start tag:", tag)
        for attr in attrs:
            print("     attr:", attr)

    def handle_endtag(self, tag):
        print("End tag  :", tag)

    def handle_data(self, data):
        print("Data     :", data)

    def handle_comment(self, data):
        print("Comment  :", data)

    def handle_entityref(self, name):
        c = chr(name2codepoint[name])
        print("Named ent:", c)

    def handle_charref(self, name):
        if name.startswith('x'):
            c = chr(int(name[1:], 16))
        else:
            c = chr(int(name))
        print("Num ent  :", c)

    def handle_decl(self, data):
        print("Decl     :", data)

parser = MyHTMLParser()

with request.urlopen("http://www.baidu.com") as b:
      html_response = b.read(1000)
      # 将 bytes 转换为 str
      html_str = html_response.decode("utf-8")
      parse_html = parser.feed(html_str)
      print(parse_html, '+++++')
# Out:
# Decl     : DOCTYPE html
# Data     :
#
# Start tag: html
# Data     :
#
# Start tag: head
# Data     :
#
# Start tag: meta
#      attr: ('http-equiv', 'Content-Type')
#      attr: ('content', 'text/html; charset=UTF-8')
# End tag  : meta
# Data     :
#
# Start tag: meta
#      attr: ('http-equiv', 'X-UA-Compatible')
#      attr: ('content', 'IE=edge,chrome=1')
# End tag  : meta
# Data     :
#
# Start tag: meta
#      attr: ('content', 'always')
#      attr: ('name', 'referrer')
# End tag  : meta
# Data     :
#
# Start tag: meta
#      attr: ('name', 'description')
#      attr: ('content', '全球领先的中文搜索引擎、致力于让网民更便捷地获取信息，找到所求。百度超过千亿的中文网页数据库，可以瞬间找到相关的搜索结果。')
# End tag  : meta
# Data     :
#
# Start tag: link
#      attr: ('rel', 'shortcut icon')
#      attr: ('href', '//www.baidu.com/favicon.ico')
#      attr: ('type', 'image/x-icon')
# End tag  : link
# Data     :
#
# Start tag: link
#      attr: ('rel', 'search')
#      attr: ('type', 'application/opensearchdescription+xml')
# ...

# %%
from matplotlib import markers, pyplot as plot


x = [1,2,3]
y = [4,5,6]

plot.plot(x, y, marker='o')
plot.plot(y, x, marker='x')

plot.show()
